# %%
import pandas as pd

# %%
# Speakers from YouTube
yt_df = pd.read_csv('Data/all_speakers_yt.csv')

# %%
yt_df
# Out:
#              speaker_name                                         talk_title  \
# 0      Nenad Palinkasevic   Failing successfully: Crypto’s complicated story
# 1              TokenBrice  Harnessing DeFi to Better DeFi: The DeFi Colle...
# 2                   Tadeo      Building collaborative lending infrastructure
# 3     Lefteris Karapetsas  Privacy is not a crime, centralization is. Bui...
# 4                 0xmikko  Scaling composable DEFI protocol to 400M from ...
# ...                   ...                                                ...
# 1047              Unknown  Panel: Autonomous worlds and bespoke execution...
# 1048                 Rich               Building Compelling Composable Games
# 1049             Tarrence                            Think Outside the Block
# 1050                  Ben  Build a Connected Sovereign Rollup with Union ...
# 1051         Simon Hudson         Creating a Decentralized Autonomous Artist
#
#            conf_name
# 0       ETH Belgrade
# ...

# %%
# Speakers from conference website
website_df = pd.read_csv('Data/all_speakers_website.csv')

# %%
website_df
# Out:
#              speaker_name                         website_url  \
# 0              John Lilic         https://www.johnlilic.info/
# 1         Solange Gueiros  https://twitter.com/solangegueiros
# 2           Dragan Rakita    https://twitter.com/rakitadragan
# 3    Simon Emanuel Schmid       https://twitter.com/schmid_si
# 4              TokenBrice      https://twitter.com/TokenBrice
# ..                    ...                                 ...
# 794       Namik Muduroglu                                 NaN
# 795       Bram Van Roelen                                 NaN
# 796           Nima Vaziri                                 NaN
# 797             Ben Fisch                                 NaN
# 798                   113                                 NaN
#
#                                             talk_title       conf_name
# 0    Pushing Blockchain Limits with Hardware Accele...    ETH Belgrade
# 1        Unlocking blockchain frontiers with Chainlink    ETH Belgrade
# ...
